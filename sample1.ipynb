# %%
a=int(input("enter number1: "))
b=int(input("enter number2: "))
c=a+b
print(c)
# Out:
# enter number1: 4
# enter number2: 8
# 12

# %%
Age=22
Mark=65.5
Name="Aysha"
Passed=True
print(type(Age))
print(type(Mark))
print(type(Name))
print(type(Passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name=input("Enter your name ")
age=int(input("Enter your age "))
mark=float(input("Enter your mark "))
print(name)
print(age)
print(mark)
# Out:
# Enter your name aysha
# Enter your age 22
# Enter your mark 70.5
# aysha
# 22
# 70.5
