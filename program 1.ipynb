# %%
n=int(input("enter the number"))
if n==1:
    print("Monday")
elif n==2:
    print("Tuesday")
elif n==3:
    print("wednesday")
elif n==4:
    print("Thursday")
elif n==5:
    print("Friday")
elif n==6:
    print("Saturday")
elif n==7:
    print("Sunday")
else :
    print("invalid input")
# Out:
# enter the number4
# Thursday

# %%
n=int(input("Enter the number"))
if n==1:
    print("January")
elif n==2:
    print("February")
elif n==3:
    print("March")
elif n==4:
    print("April")
elif n==5:
    print("May")
elif n==6:
    print("June")
elif n==7:
    print("July")
elif n==8:
    print("August")
elif n==9:
    print("September")
elif n==10:
    print("October")
elif n==11:
    print("November")
elif n==12:
    print("December")
else :
    print("invalid input")
# Out:
# Enter the number11
# November

# %%
a=int(input("Enter a number"))
if (a%3==0 and a%5==0):
    print("The number is Divisible by both 3 and 5")
elif (a%3==0):
    print("The number is only Divisible by 3 ")
elif (a%5==0):
    print("The number is only Divisible by 5 ")
else :
    print("Not Divisible by both 3 and 5 ")
# Out:
# Enter a number20
# The number is only Divisible by 5

# %%
n=int(input("Enter a number: "))
if(n%7==0):
    print("The number is divisible by 7")
else:
    print("The number is not divisible by ")
# Out:
# Enter a number: 7
# The number is divisible by 7

# %%
a=input("Enter a letter: ")
vowels ="aeiouAEIOU"
if a in vowels:
    print(" Is a vowel")
else:
    print("Is not a vowel ")
# Out:
# Enter a letter: a
#  Is a vowel

# %%
a=int(input("Enter your age : "))
if(a>=18):
    print("you are eligible for Driving licence")
else:
    print("your are not eligible for Driving licence")
# Out:
# Enter your age : 18
# you are eligible for Driving licence

# %%
a=input("Enter a string: ")
b=input("Enter another string:")
if (a==b):
    print("Both are same")
else:
    print("Not same")
# Out:
# Enter a string: hey
# Enter another string:hi
# Not same

# %%
a=int(input("Enter the bill amount:"))
if (a>5000):
    print("Customer is eligible for a discount")
else:
    print("Customer is not eligible for the discount")
# Out:
# Enter the bill amount:4000
# Customer is not eligible for the discount

# %%
a=int(input("Enter a number :"))
if (10<=a<=100):
    print("The number lies between 10 and 100 ")
else :
    print("Not lies between 10 and 100")
# Out:
# Enter a number :69
# The number lies between 10 and 100

# %%
le=input(" Enter a letter :")
if(le>='A' and le<='Z'):
    print("upper case letter")
elif(le>='a' and le<='z'):
    print("lowercase letter")
else:
    ("no output")
# Out:
#  Enter a letter :Z
# upper case letter

# %%
mark=[10,20,30,40,50]
print(mark[3])
# Out:
# 40

# %%
l=[10,20,40,50]
l.append(60)
print(l)
# Out:
# [10, 20, 40, 50, 60]

# %%
number=(2,4,6,8)
print(number[3])
# Out:
# 8

# %%
s={10,15,20,25,30,25}
print(s)
# Out:
# {20, 25, 10, 30, 15}

# %%
a={"name":"Anu","age":22}
print(a)
# Out:
# {'name': 'Anu', 'age': 22}

# %%
name="aysha"
print(name[0])
print(name[-1])
# Out:
# a
# a
